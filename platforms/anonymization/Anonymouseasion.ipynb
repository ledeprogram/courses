# %%
# For parsing the csv
import csv
import urllib2
import StringIO

# For actual computations
import random as rand 
import pandas as pd

# %% [markdown]
# Let's import some name information into a csv.

# %%
girl_names_url = 'https://raw.githubusercontent.com/ledeprogram/courses/master/platforms/anonymization/female_baby_names.csv'
girl_response = urllib2.urlopen(girl_names_url)

guy_names_url = 'https://raw.githubusercontent.com/ledeprogram/courses/master/platforms/anonymization/male_baby_names.csv'
guy_response = urllib2.urlopen(guy_names_url)

girl_names = pd.read_csv(girl_response)
guy_names = pd.read_csv(guy_response)

# %%
# Out:
#          MARY  2.629  3991060   1
# 0    PATRICIA  1.073  1628911   2
# 1       LINDA  1.035  1571224   3
# 2     BARBARA  0.980  1487729   4
# 3   ELIZABETH  0.937  1422451   5
# 4    JENNIFER  0.932  1414861   6
# 5       MARIA  0.828  1256979   7
# 6       SUSAN  0.794  1205364   8
# 7    MARGARET  0.768  1165894   9
# 8     DOROTHY  0.727  1103652  10
# 9        LISA  0.704  1068736  11
# 10      NANCY  0.669  1015603  12
# 11      KAREN  0.667  1012567  13
# 12      BETTY  0.666  1011048  14
# 13      HELEN  0.663  1006494  15
# 14     SANDRA  0.629   954879  16
# 15      DONNA  0.583   885047  17
# 16      CAROL  0.565   857721  18
# 17       RUTH  0.562   853167  19
# 18     SHARON  0.522   792443  20
# 19   MICHELLE  0.519   787889  21
# 20      LAURA  0.510   774226  22
# 21      SARAH  0.508   771190  23
# 22   KIMBERLY  0.504   765118  24
# 23    DEBORAH  0.494   749937  25
# 24    JESSICA  0.490   743864  26
# 25    SHIRLEY  0.482   731720  27
# 26    CYNTHIA  0.469   711985  28
# 27     ANGELA  0.468   710466  29
# 28    MELISSA  0.462   701358  30
# 29     BRENDA  0.455   690731  31
# 30        AMY  0.451   684659  32
# 31       ANNA  0.440   667960  33
# 32    REBECCA  0.430   652779  34
# 33   VIRGINIA  0.430   652779  35
# 34   KATHLEEN  0.424   643670  36
# 35     PAMELA  0.416   631526  37
# 36     MARTHA  0.412   625453  38
# 37      DEBRA  0.408   619381  39
# 38     AMANDA  0.404   613309  40
# 39  STEPHANIE  0.400   607236  41
# 40    CAROLYN  0.385   584465  42
# 41  CHRISTINE  0.382   579911  43
# 42      MARIE  0.379   575356  44
# 43      JANET  0.379   575356  45
# 44  CATHERINE  0.373   566248  46
# 45    FRANCES  0.370   561694  47
# 46        ANN  0.364   552585  48
# 47      JOYCE  0.364   552585  49
# 48      DIANE  0.359   544995  50
# 49      ALICE  0.357   541958  51
# 50      JULIE  0.348   528296  52
# 51    HEATHER  0.337   511597  53
# 52     TERESA  0.336   510078  54
# 53      DORIS  0.335   508560  55
# 54     GLORIA  0.335   508560  56
# 55     EVELYN  0.322   488825  57
# 56       JEAN  0.315   478199  58
# 57     CHERYL  0.315   478199  59
# 58    MILDRED  0.313   475162  60
# 59  KATHERINE  0.313   475162  61
#           ...    ...      ... ...
#
# [1000 rows x 4 columns]
